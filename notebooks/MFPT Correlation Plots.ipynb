# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# %matplotlib inline

# %%
# Import the ISOMAP results
im_coors = np.load('.\\Sherlock_Data\\isomap_coordinates_30_40_97.dat')
im_cluster_labels = np.load('.\\Sherlock_Data\\isomap_clustering_labels_30_40_97.dat')

# Import the MSM builder results
msm_cluster_labels = np.load('.\\Sherlock_Data\\msm_clustering_labels.dat')
msm_mfpt_mat = np.load('.\\Sherlock_Data\\msm_mfpt_mat.dat')
msm_flux_mat = np.load('.\\Sherlock_Data\\msm_flux_mat.dat')

msm_mfpt_sym = (msm_mfpt_mat + msm_mfpt_mat.transpose())/2
num_frames = im_cluster_labels.shape[0]

# select frames to compare to each other
indices = range(num_frames)
np.random.shuffle(indices)
indices = indices[:100]

im_dist = []
mfpt = []
flux = []
# Collect ISOMAP distances and MFTPS
for (idx1, frame1) in enumerate(indices):
    for (idx2, frame2) in enumerate(indices[(idx1+1):]):
        if msm_cluster_labels[frame1] is not msm_cluster_labels[frame2]:
            im_dist.append( np.linalg.norm(im_coors[frame1, :] - im_coors[frame2, :])  )
#             mfpt.append( min( msm_mfpt_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]], 
#                               msm_mfpt_mat[msm_cluster_labels[frame1]][msm_cluster_labels[frame2]]))
            mfpt.append(msm_mfpt_sym[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])
            flux.append(msm_flux_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])

x = np.array(im_dist)
y = np.log(np.log(np.array(mfpt)))
idx = np.invert(np.isnan(y))*range(len(x))
x = x[idx]
y = y[idx]
y_1 = np.array(flux)[idx]

plt.scatter(x,y)
plt.xlabel('ISOMAP distance')
plt.ylabel('MFPT')
plt.show()
plt.scatter(x, y_1)
plt.xlabel('ISOMAP distance')
plt.ylabel('Flux')
plt.show()

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print r_value**2
print r_value
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: RuntimeWarning: invalid value encountered in log
# 0.423479077948
# 0.650752701068

# %%
# Import the ISOMAP results
im_coors = np.load('.\\Sherlock_Data\\isomap_coordinates_30_45_97.dat')
im_cluster_labels = np.load('.\\Sherlock_Data\\isomap_clustering_labels_30_45_97.dat')

# Import the MSM builder results
msm_cluster_labels = np.load('.\\Sherlock_Data\\msm_clustering_labels.dat')
msm_mfpt_mat = np.load('.\\Sherlock_Data\\msm_mfpt_mat.dat')
msm_flux_mat = np.load('.\\Sherlock_Data\\msm_flux_mat.dat')

msm_mfpt_sym = (msm_mfpt_mat + msm_mfpt_mat.transpose())/2
num_frames = im_cluster_labels.shape[0]

# select frames to compare to each other
indices = range(num_frames)
np.random.shuffle(indices)
indices = indices[:100]

im_dist = []
mfpt = []
flux = []
# Collect ISOMAP distances and MFTPS
for (idx1, frame1) in enumerate(indices):
    for (idx2, frame2) in enumerate(indices[(idx1+1):]):
        if msm_cluster_labels[frame1] is not msm_cluster_labels[frame2]:
            im_dist.append( np.linalg.norm(im_coors[frame1, :] - im_coors[frame2, :])  )
#             mfpt.append( min( msm_mfpt_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]], 
#                               msm_mfpt_mat[msm_cluster_labels[frame1]][msm_cluster_labels[frame2]]))
            mfpt.append(msm_mfpt_sym[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])
            flux.append(msm_flux_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])

x = np.array(im_dist)
y = np.log(np.log(np.array(mfpt)))
idx = np.invert(np.isnan(y))*range(len(x))
x = x[idx]
y = y[idx]
y_1 = np.array(flux)[idx]

plt.scatter(x,y)
plt.xlabel('ISOMAP distance')
plt.ylabel('MFPT')
plt.show()
plt.scatter(x, y_1)
plt.xlabel('ISOMAP distance')
plt.ylabel('Flux')
plt.show()

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
print r_value**2
print r_value
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:32: RuntimeWarning: invalid value encountered in log
# 0.518486723193
# 0.720060221921

# %%
# Import the ISOMAP results
im_coors = np.load('.\\Sherlock_Data\\isomap_coordinates_35_40_97.dat')
im_cluster_labels = np.load('.\\Sherlock_Data\\isomap_clustering_labels_35_40_97.dat')

# Import the MSM builder results
msm_cluster_labels = np.load('.\\Sherlock_Data\\msm_clustering_labels.dat')
msm_mfpt_mat = np.load('.\\Sherlock_Data\\msm_mfpt_mat.dat')
msm_flux_mat = np.load('.\\Sherlock_Data\\msm_flux_mat.dat')

msm_mfpt_sym = (msm_mfpt_mat + msm_mfpt_mat.transpose())/2
num_frames = im_cluster_labels.shape[0]

# select frames to compare to each other
indices = range(num_frames)
np.random.shuffle(indices)
indices = indices[:100]

im_dist = []
mfpt = []
flux = []
# Collect ISOMAP distances and MFTPS
for (idx1, frame1) in enumerate(indices):
    for (idx2, frame2) in enumerate(indices[(idx1+1):]):
        if msm_cluster_labels[frame1] is not msm_cluster_labels[frame2]:
            im_dist.append( np.linalg.norm(im_coors[frame1, :] - im_coors[frame2, :])  )
#             mfpt.append( min( msm_mfpt_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]], 
#                               msm_mfpt_mat[msm_cluster_labels[frame1]][msm_cluster_labels[frame2]]))
            mfpt.append(msm_mfpt_sym[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])
            flux.append(msm_flux_mat[msm_cluster_labels[frame2]][msm_cluster_labels[frame1]])
plt.scatter(np.array(im_dist), np.log(np.array(mfpt)))
plt.xlabel('ISOMAP distance')
plt.ylabel('MFPT')
plt.show()
plt.scatter(np.array(im_dist), np.array(flux))
plt.xlabel('ISOMAP distance')
plt.ylabel('Flux')
plt.show()
# Out:
# C:\Users\minch_000\Anaconda2\lib\site-packages\ipykernel\__main__.py:30: RuntimeWarning: divide by zero encountered in log

# %%
np.where(msm_cluster_labels == 59)
# Out:
# (array([ 1425,  1430,  1435,  1538,  1653,  1654,  1943,  2851,  2893,
#          3234,  3263,  3271,  3293,  3326,  3609,  3653,  3654,  3656,
#          3803,  3806,  3807,  3811,  8732,  8733,  9155,  9174,  9176,
#          9179,  9185,  9186,  9187,  9194,  9205,  9206,  9208,  9214,
#          9216,  9218,  9220,  9222,  9230,  9231,  9232,  9234,  9235,
#          9236,  9237,  9238,  9239,  9240,  9242,  9243,  9244,  9245,
#          9247,  9249,  9250,  9252,  9253,  9254,  9255,  9256,  9257,
#          9258,  9259,  9260,  9263,  9264,  9265,  9271,  9272,  9274,
#          9277,  9279,  9280,  9282,  9283,  9284,  9285,  9288,  9289,
#          9292,  9295,  9300,  9303,  9304,  9308,  9310,  9311,  9312,
#          9314,  9315,  9316,  9317,  9318,  9319,  9320,  9321,  9323,
#          9324,  9328,  9330,  9332,  9334,  9336,  9338,  9339,  9340,
#          9341,  9342,  9346,  9348,  9349,  9350,  9354,  9361,  9363,
# ...
